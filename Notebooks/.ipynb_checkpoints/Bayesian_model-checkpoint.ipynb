# %% [markdown]
# # Load data and model

# %%
#Load libraries:
library("here")
library(ggplot2)
library("rethinking")
library("bayesplot")
library(viridis)
library(RColorBrewer)
library(corrplot)

# %%
m<-readRDS(here("outputs","BayesianModels","m.archaeology.rds"))

# %%
posterior <- as.matrix(m) # Get posterior predictions for plots
bayesplot_theme_set(new = theme_classic()) # Set theme for bayesplot

# %%
mname<-"m.archaeology"

# %%
# Set output directories:
path2trankplot<-here("outputs","BayesianModels","diagnostics",paste(mname,"trankplot.pdf",sep="_"))
path2traceplot<-here("outputs","BayesianModels","diagnostics",paste(mname,"traceplot.png",sep="_"))
path2posteriorInt<-here("outputs","BayesianModels","",paste(mname,"posteriorInt.png",sep="_"))
path2posteriorIntUsers<-here("outputs","BayesianModels","",paste(mname,"posteriorIntUsers.png",sep="_"))
path2posterior<-here("outputs","BayesianModels","",paste(mname,"posterior.png",sep="_"))
path2corrplot<-here("outputs","BayesianModels","",paste(mname,"correlations.png",sep="_"))

# %% [markdown]
# ## Model specification ##
# $$R_i \sim ZIPoisson(p_i, λ_i)$$
#
# $$logit(p_i) = α_p + β_p*F_i$$
#
# $$α_p \sim Normal(-1.5,1)$$
#
# $$β_p \sim Normal(0,0.5)$$
#
#
# $$log(λ_i) = α\_topic[topic] + α\_user[user] + β_F*F_i + β_S*S_i + β_{TL}*\sum_{j=0}^{TL_i -1} \delta_j$$
#
#
# $$ α\_topic \sim Normal(\widehat{\alpha},σ_T) $$
# $$ α\_user \sim Normal(0,σ_U) $$
#
# $$ \widehat{\alpha} \sim Normal (3,1)$$
#
# $$ σ_T,σ_U \sim Cauchy(1,0.5) $$
#
# $$β_F, β_S, β_T \sim Normal(0,0.2)$$
#
# $$ \sim \gamma ~ Dirichlet([2,2,2,2])$$

# %% [markdown]
# # Model diagnostics
#
# The table belowe shows parameters estimates together with Rhat value and the number of effective samples. All the Rhat value are close to 1, as they should be.

# %%
precis(m,depth=2)
# Out:
#                 mean        sd           5.5%         94.5%        n_eff
# alpha_topic[1]   1.47170446 0.3540352873  0.936742890  2.088289600   293.7541
# alpha_topic[2]   2.08976591 0.3541485837  1.554454700  2.706322600   293.9312
# alpha_topic[3]   2.03214591 0.3540934697  1.495556800  2.648250700   294.0755
# alpha_topic[4]   3.59487637 0.3540136367  3.061074050  4.210449500   293.4706
# alpha_topic[5]   1.35962578 0.3540623527  0.824037115  1.976124300   293.5352
# alpha_topic[6]   1.63023834 0.3540670648  1.094820050  2.249382750   293.1909
# alpha_topic[7]   1.48568141 0.3540779211  0.949606560  2.101997700   293.4731
# alpha_topic[8]   1.93632635 0.3540420115  1.403841350  2.557057700   292.4470
# alpha_topic[9]   3.00832571 0.3540353835  2.473340100  3.622856850   293.5836
# alpha_topic[10]  3.23957203 0.3540059183  2.705729000  3.856627150   293.3696
# alpha_topic[11]  1.81579157 0.3541843295  1.282197450  2.431002650   295.0932
# alpha_topic[12]  2.97756263 0.3540095773  2.443808900  3.592747700   293.2698
# alpha_topic[13]  3.37964101 0.3540001707  2.844739750  3.995877700   293.1125
# alpha_topic[14]  2.60755367 0.3539130685  2.073463500  3.224604550   293.0739
# alpha_topic[15]  3.36210309 0.3539945296  2.829146650  3.978004400   293.6384
# alpha_topic[16]  3.31237475 0.3539795169  2.777920650  3.929481100   293.6433
# alpha_topic[17]  3.29731407 0.3540472792  2.763524500  3.911779850   293.5697
# alpha_topic[18]  2.91032141 0.3540846742  2.376746150  3.525917500   292.8859
# alpha_topic[19]  1.74839964 0.3542669953  1.212071200  2.366235200   293.4227
# alpha_topic[20]  2.82011833 0.3540613216  2.286440100  3.435424800   293.7428
# alpha_topic[21]  1.35963317 0.3548308945  0.826452860  1.976990700   293.7182
# alpha_topic[22]  1.47815433 0.3543066792  0.944431590  2.092710250   294.7221
# alpha_user[1]   -0.46247834 0.3540140724 -1.078538700  0.071015335   293.5180
# alpha_user[2]    0.66114751 0.3540200991  0.044435321  1.194877150   293.5050
# alpha_user[3]   -0.63813236 0.3539979559 -1.253150700 -0.102194030   293.4279
# alpha_user[4]    0.13074680 0.3540562914 -0.485841380  0.664759890   293.3888
# alpha_bar        2.42387997 0.3836988989  1.845221300  3.070770650   355.7743
# ap              -0.07071074 0.0056996812 -0.079787027 -0.061570269  8769.9424
# bp              -0.77372196 0.0556631888 -0.866175515 -0.689020700  7291.8485
# bF              -0.00448077 0.0009527986 -0.006028614 -0.002968825 10461.7729
# bS               0.07700164 0.0010593449  0.075340094  0.078682955 10711.5028
# sigma_topic      0.81403643 0.1264935751  0.637477690  1.032547600  6592.1656
# sigma_user       0.71121154 0.3459912418  0.370227945  1.303322750  1923.4331
# bT              -0.26269471 0.0582460044 -0.368618605 -0.186622120  3122.8429
# delta[1]         0.21073608 0.0477487552  0.138764025  0.292003825  3429.5966
# delta[2]         0.39229249 0.0835094091  0.261621345  0.527374385  4127.6583
# delta[3]         0.03442582 0.0240544950  0.006558872  0.078631914  7169.9216
# delta[4]         0.21664078 0.1158127948  0.051991199  0.421996895  4199.0627
# delta[5]         0.14590482 0.0888938070  0.030863704  0.307741740  6461.8387
#                 Rhat4
# alpha_topic[1]  1.0176496
# alpha_topic[2]  1.0175814
# alpha_topic[3]  1.0175879
# alpha_topic[4]  1.0176389
# alpha_topic[5]  1.0176141
# alpha_topic[6]  1.0176186
# alpha_topic[7]  1.0176651
# alpha_topic[8]  1.0176845
# alpha_topic[9]  1.0176599
# alpha_topic[10] 1.0176356
# alpha_topic[11] 1.0175900
# alpha_topic[12] 1.0176338
# alpha_topic[13] 1.0176913
# alpha_topic[14] 1.0176170
# alpha_topic[15] 1.0176426
# alpha_topic[16] 1.0176298
# alpha_topic[17] 1.0176340
# alpha_topic[18] 1.0177367
# alpha_topic[19] 1.0176442
# alpha_topic[20] 1.0176022
# alpha_topic[21] 1.0175994
# alpha_topic[22] 1.0176482
# alpha_user[1]   1.0176382
# alpha_user[2]   1.0176431
# alpha_user[3]   1.0176499
# alpha_user[4]   1.0176521
# alpha_bar       1.0145149
# ap              0.9998782
# bp              1.0000671
# bF              0.9997234
# bS              1.0002479
# sigma_topic     1.0000579
# sigma_user      1.0031005
# bT              1.0010872
# delta[1]        1.0005670
# delta[2]        1.0004296
# delta[3]        1.0000776
# delta[4]        1.0002437
# delta[5]        1.0004946

# %% [markdown]
# In addition to that, the trankplots and traceplots shown below show healthy chains which mixed well.

# %%
#pdf(path2trankplot,width = 17, height = 29) 
options(repr.plot.width=8.85,repr.plot.height=12.85,repr.plot.res=200)
trankplot(m)
#dev.off()
# Out:
# Waiting to draw page 2 of 3
#
# Waiting to draw page 3 of 3
# plot without title
# plot without title
# plot without title

# %%
color_scheme_set("blue")

# %%
posterior2 <- extract(m, inc_warmup = TRUE, permuted = FALSE)

# %%
p <- mcmc_trace(posterior2, n_warmup = 2500)+facet_text(size = 5)+theme( strip.background = element_blank(),axis.text.x = element_text(size=5) )

# %%
p
# Out:
# plot without title

# %%
ggsave(path2traceplot,p,width = 29, height = 29,unit="cm",create.dir=TRUE)

# %% [markdown]
# # Interpretation

# %% [markdown]
# ### Predicting number of retweets, if seen.
#
# The other parameters **bF**, **bS**, **bT** and intercepts within **alpha_topic** and **alpha user** vector inform about how the topic user category, the number of followers and the sentiment and threath affect the number of retweets if the tweets has been seen by sombody willing to retweet. The figure below shows the posterior distributions fot the intercept values for different topic from the highest to lowest, with the higher value corresponding to higher increase rate for retweets. Then similiar figures are drawn for other parameters.

# %%
tab<-precis(m,depth=2,pars="alpha_topic")

# %%
labels<-read.csv(here("outputs","TopicModels","tweets","Topics - Tweets.csv")) # Load topic labels

# %%
table<-cbind(labels[,colnames(labels)%in%c("Consolidated","X")],tab)

# %%
df<- table[order(table$mean,decreasing=TRUE),]

# %%
write.csv(df,here("outputs","BayesianModels",paste("topic_intercepts",mname,".csv",sep="")))

# %%
#png(path2posteriorInt,width = 15, height = 15,res=300,unit="cm") 
options(repr.plot.width=6.85,repr.plot.height=6.85,repr.plot.res=200)
mcmc_areas(posterior,par=c("alpha_bar",rownames(df)),prob_outer = 0.95,prob=0.8)+
scale_y_discrete(labels=rev(c("distribution mean",paste(df$X,df$Consolidated,sep=". "))),limits=rev)
#dev.off()
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# plot without title

# %%
tab<-precis(m,depth=2,pars="alpha_user")

# %%
labels<-read.csv(here("outputs","TopicModels","users","Topics - Users.csv")) # Load topic labels
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '/home/sm1mkr/Documents/GitHub/TwitterArchaeology/outputs/TopicModels/users/Topics - Users.csv'”

# %%
labels
# Out:
#   Topics Label..Chiara.                               Label..Marta.
# 1 1      News and cultural heritage professional      NA
# 2 2      Academic archaeologist/historian             NA
# 3 3      Other identities (professional and personal) NA
# 4 4      Motivation and goal pursuit                  NA
#   Label..Alberto.
# 1 News and cultural heritage professional
# 2 Academic archaeologist/historian
# 3 Amateur archaeologist - creative professions
# 4 Life pespectives / insights
#   Consolidated
# 1 News and cultural heritage professional
# 2 Academic archaeologist/historian
# 3 Hobbies and creative professions
# 4 Perspectives on life/the world

# %%
table<-cbind(labels[,colnames(labels)%in%c("Consolidated","Topics")],tab)
df2<- table[order(table$mean,decreasing=TRUE),]

# %%
df2
# Out:
#               Topics Consolidated                            mean
# alpha_user[2] 2      Academic archaeologist/historian         0.6611475
# alpha_user[4] 4      Perspectives on life/the world           0.1307468
# alpha_user[1] 1      News and cultural heritage professional -0.4624783
# alpha_user[3] 3      Hobbies and creative professions        -0.6381324
#               sd        5.5%        94.5%       n_eff    Rhat4
# alpha_user[2] 0.3540201  0.04443532  1.19487715 293.5050 1.017643
# alpha_user[4] 0.3540563 -0.48584138  0.66475989 293.3888 1.017652
# alpha_user[1] 0.3540141 -1.07853870  0.07101534 293.5180 1.017638
# alpha_user[3] 0.3539980 -1.25315070 -0.10219403 293.4279 1.017650

# %%
write.csv(df2,here("outputs","BayesianModels",paste("users_intercepts",mname,".csv",sep="")))

# %%
#png(path2posteriorIntUsers,width = 15, height = 15,res=300,unit="cm") 

options(repr.plot.width=6.85,repr.plot.height=6.85,repr.plot.res=200)
mcmc_areas(posterior,par=c(paste("alpha_user[",df2$Topics,"]",sep="")),prob_outer = 0.95,prob=0.8)+
scale_y_discrete(labels=rev(paste(df2$Topics,df2$Label..Chiara,sep=". ")),limits=rev)

#dev.off()
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# plot without title

# %% [markdown]
# # Other parameters:

# %%
#png(path2posterior,width = 15, height = 7,res=300,unit="cm") 
options(repr.plot.width=4.85,repr.plot.height=2.85,repr.plot.res=200)
mcmc_areas(posterior,par=c("ap","bp","bS","bF","bT"),prob_outer = 0.95, prob=0.8)

#dev.off()
# Out:
# plot without title
